# %% [markdown]
# # Recommendation System for Amazon Clothing Products
# ---
# ## 4. Content Based Recommendation System
#
# *Author*: Mariam Elsayed
#
# *Contact*: mariamkelsayed@gmail.com
#
# *Notebook*: 4 of 5
#
# *Previous Notebook*: `popularity_rec.ipynb`
#
# *Next Notebook*: `colab_rec.ipynb`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Table of Contents
#
# * [Introduction](#intro)
#
# * [Loading the Data](#loading)
#
# * [Content Based Recommendation System](#rec)
#
#     * [Using Cosine Similarity](#cosine)
#
#     * [Creating a General Function](#function)
#
# * [Conclusion](#conc)

# %% [markdown]
# ## Introduction <a class="anchor" id="intro"></a>
#
# Next let's create a content based recommendation system. This would rely on ranking how similar different products are based on their description.

# %% [markdown]
# ## Loading the Data <a class="anchor" id="loading"></a>
#
# This recommendation system will use the products data created in the preprocessing notebooks.

# %%
# Reading the data
products_df = pd.read_csv('Data/products_cleaned.csv')

# %%
products_df
# Out:
#                                                  category  \
# 0       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 1       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 2       ['Clothing, Shoes & Jewelry', 'Novelty & More'...
# 3       ['Clothing, Shoes & Jewelry', 'Women', 'Clothi...
# 4       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# ...                                                   ...
# 678727  ['Clothing, Shoes & Jewelry', 'Men', 'Accessor...
# 678728  ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', ...
# 678729  ['Clothing, Shoes & Jewelry', 'Women', 'Clothi...
# 678730  ['Clothing, Shoes & Jewelry', 'Baby', 'Baby Gi...
# 678731  ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', ...
#
#                                               description  \
# 0       The Hottest Bag in Town! Brand: Anello Conditi...
# 1       The Hottest Bag in Town! Brand: Anello Conditi...
# 2       Brand New.  Hat Centre Length: adult about 8cm...
# 3       Please allow 1-2cm dimension deviation. 100% b...
# 4       2 Way Shoulder Handle Polyester Canvas Boston ...
# ...                                                   ...
# 678727  Get maximum protection from the elements. Clif...
# 678728  A classic wingtip with a subtle twist that cov...
# 678729  Our classy but sexy strappy sheath cocktail wi...
# 678730  Size Length Hip*2 Age Advice 70 39.5 CM 30 CM ...
# 678731  This classic plain toe style is anything but p...
#
#                                                     title      brand  \
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...     Anello
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...     Anello
# 2       bettyhome Unisex Adult Winter Spring Thicken C...  bettyhome
# 3       bettyhome Womens Lace Short Sleeves Top Printi...  bettyhome
# 4       Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...     Anello
# ...                                                   ...        ...
# 678727             Kaenon Cliff Sunglasses - Select Color     Kaenon
# 678728                    Deer Stags Men's Hampden Oxford    Unknown
# 678729  Laundry by Shelli Segal Women's Fitted Strappy...    Unknown
# 678730  Newborn Baby Girl Bodysuit Lace Floral Romper ...     Hotone
# 678731                       Deer Stags Men's Lohi Oxford    Unknown
#
#             rank        asin  \
# 0        3994472  0204444454
# 1         635761  0204444403
# 2        5061041  0206313535
# 3       10635107  0206335962
# 4        1615335  024444448X
# ...          ...         ...
# 678727   1908928  B01HJH6SA2
# 678728    956501  B01HJH7W0W
# 678729   3633844  B01HJI0G5Y
# 678730   1671980  B01HJHR8A6
# 678731   1228949  B01HJH8JBI
#
#                                                  imageURL   price  \
# 0       ['https://images-na.ssl-images-amazon.com/imag...   70.00
# 1       ['https://images-na.ssl-images-amazon.com/imag...   65.99
# 2       ['https://images-na.ssl-images-amazon.com/imag...   18.99
# 3       ['https://images-na.ssl-images-amazon.com/imag...   23.99
# 4       ['https://images-na.ssl-images-amazon.com/imag...   65.33
# ...                                                   ...     ...
# 678727  ['https://images-na.ssl-images-amazon.com/imag...  199.00
# 678728  ['https://images-na.ssl-images-amazon.com/imag...   52.38
# 678729  ['https://images-na.ssl-images-amazon.com/imag...   18.99
# 678730  ['https://images-na.ssl-images-amazon.com/imag...    4.99
# 678731  ['https://images-na.ssl-images-amazon.com/imag...   54.12
#
#         maincat_Luggage & Travel Gear  maincat_Backpacks  ...  subcat_Shoes  \
# 0                                True               True  ...         False
# 1                                True               True  ...         False
# 2                               False              False  ...         False
# 3                               False              False  ...         False
# 4                                True               True  ...         False
# ...                               ...                ...  ...           ...
# 678727                          False              False  ...         False
# 678728                          False              False  ...          True
# 678729                          False              False  ...         False
# 678730                          False              False  ...         False
# 678731                          False              False  ...          True
#
#         subcat_Handbags & Wallets  subcat_Girls  subcat_Boys  \
# 0                           False         False        False
# 1                           False         False        False
# 2                           False         False        False
# 3                           False         False        False
# 4                           False         False        False
# ...                           ...           ...          ...
# 678727                      False         False        False
# 678728                      False         False        False
# 678729                      False         False        False
# 678730                      False         False        False
# 678731                      False         False        False
#
#         subcat_Shoe, Jewelry & Watch Accessories  subcat_Jewelry Accessories  \
# 0                                          False                       False
# 1                                          False                       False
# 2                                          False                       False
# 3                                          False                       False
# 4                                          False                       False
# ...                                          ...                         ...
# 678727                                     False                       False
# 678728                                     False                       False
# 678729                                     False                       False
# 678730                                     False                       False
# 678731                                     False                       False
#
#         subcat_Shoe Care & Accessories  subcat_Contemporary & Designer  \
# 0                                False                           False
# 1                                False                           False
# 2                                False                           False
# 3                                False                           False
# 4                                False                           False
# ...                                ...                             ...
# 678727                           False                           False
# 678728                           False                           False
# 678729                           False                           False
# 678730                           False                           False
# 678731                           False                           False
#
#         subcat_Travel Accessories  subcat_Surf, Skate & Street
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 678727                      False                        False
# 678728                      False                        False
# 678729                      False                        False
# 678730                      False                        False
# 678731                      False                        False
#
# [678732 rows x 62 columns]

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678732 entries, 0 to 678731
# Data columns (total 62 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   category                                   678732 non-null  object
#  1   description                                678530 non-null  object
#  2   title                                      678732 non-null  object
#  3   brand                                      678732 non-null  object
#  4   rank                                       678732 non-null  int64
#  5   asin                                       678732 non-null  object
#  6   imageURL                                   550904 non-null  object
#  7   price                                      678732 non-null  float64
#  8   maincat_Luggage & Travel Gear              678732 non-null  bool
#  9   maincat_Backpacks                          678732 non-null  bool
#  10  maincat_Novelty & More                     678732 non-null  bool
#  11  maincat_Clothing                           678732 non-null  bool
#  12  maincat_Women                              678732 non-null  bool
#  13  maincat_Baby                               678732 non-null  bool
#  14  maincat_Baby Boys                          678732 non-null  bool
#  15  maincat_Men                                678732 non-null  bool
#  16  maincat_Maternity                          678732 non-null  bool
#  17  maincat_Baby Girls                         678732 non-null  bool
#  18  maincat_Traditional & Cultural Wear        678732 non-null  bool
#  19  maincat_Accessories                        678732 non-null  bool
#  20  maincat_Jewelry                            678732 non-null  bool
#  21  maincat_Costumes & Accessories             678732 non-null  bool
#  22  maincat_Watches                            678732 non-null  bool
#  23  maincat_Kids & Baby                        678732 non-null  bool
#  24  maincat_Uniforms, Work & Safety            678732 non-null  bool
#  25  maincat_Shoes                              678732 non-null  bool
#  26  maincat_Handbags & Wallets                 678732 non-null  bool
#  27  maincat_Girls                              678732 non-null  bool
#  28  maincat_Boys                               678732 non-null  bool
#  29  maincat_Shoe, Jewelry & Watch Accessories  678732 non-null  bool
#  30  maincat_Jewelry Accessories                678732 non-null  bool
#  31  maincat_Shoe Care & Accessories            678732 non-null  bool
#  32  maincat_Contemporary & Designer            678732 non-null  bool
#  33  maincat_Travel Accessories                 678732 non-null  bool
#  34  maincat_Surf, Skate & Street               678732 non-null  bool
#  35  subcat_Luggage & Travel Gear               678732 non-null  bool
#  36  subcat_Backpacks                           678732 non-null  bool
#  37  subcat_Novelty & More                      678732 non-null  bool
#  38  subcat_Clothing                            678732 non-null  bool
#  39  subcat_Women                               678732 non-null  bool
#  40  subcat_Baby                                678732 non-null  bool
#  41  subcat_Baby Boys                           678732 non-null  bool
#  42  subcat_Men                                 678732 non-null  bool
#  43  subcat_Maternity                           678732 non-null  bool
#  44  subcat_Baby Girls                          678732 non-null  bool
#  45  subcat_Traditional & Cultural Wear         678732 non-null  bool
#  46  subcat_Accessories                         678732 non-null  bool
#  47  subcat_Jewelry                             678732 non-null  bool
#  48  subcat_Costumes & Accessories              678732 non-null  bool
#  49  subcat_Watches                             678732 non-null  bool
#  50  subcat_Kids & Baby                         678732 non-null  bool
#  51  subcat_Uniforms, Work & Safety             678732 non-null  bool
#  52  subcat_Shoes                               678732 non-null  bool
#  53  subcat_Handbags & Wallets                  678732 non-null  bool
#  54  subcat_Girls                               678732 non-null  bool
#  55  subcat_Boys                                678732 non-null  bool
#  56  subcat_Shoe, Jewelry & Watch Accessories   678732 non-null  bool
#  57  subcat_Jewelry Accessories                 678732 non-null  bool
#  58  subcat_Shoe Care & Accessories             678732 non-null  bool
#  59  subcat_Contemporary & Designer             678732 non-null  bool
#  60  subcat_Travel Accessories                  678732 non-null  bool
#  61  subcat_Surf, Skate & Street                678732 non-null  bool
# dtypes: bool(54), float64(1), int64(1), object(6)
# memory usage: 76.4+ MB

# %%
# Dropping products with no description
products_df = products_df.dropna(axis=0, subset=['description'])

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 678530 entries, 0 to 678731
# Data columns (total 62 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   category                                   678530 non-null  object
#  1   description                                678530 non-null  object
#  2   title                                      678530 non-null  object
#  3   brand                                      678530 non-null  object
#  4   rank                                       678530 non-null  int64
#  5   asin                                       678530 non-null  object
#  6   imageURL                                   550712 non-null  object
#  7   price                                      678530 non-null  float64
#  8   maincat_Luggage & Travel Gear              678530 non-null  bool
#  9   maincat_Backpacks                          678530 non-null  bool
#  10  maincat_Novelty & More                     678530 non-null  bool
#  11  maincat_Clothing                           678530 non-null  bool
#  12  maincat_Women                              678530 non-null  bool
#  13  maincat_Baby                               678530 non-null  bool
#  14  maincat_Baby Boys                          678530 non-null  bool
#  15  maincat_Men                                678530 non-null  bool
#  16  maincat_Maternity                          678530 non-null  bool
#  17  maincat_Baby Girls                         678530 non-null  bool
#  18  maincat_Traditional & Cultural Wear        678530 non-null  bool
#  19  maincat_Accessories                        678530 non-null  bool
#  20  maincat_Jewelry                            678530 non-null  bool
#  21  maincat_Costumes & Accessories             678530 non-null  bool
#  22  maincat_Watches                            678530 non-null  bool
#  23  maincat_Kids & Baby                        678530 non-null  bool
#  24  maincat_Uniforms, Work & Safety            678530 non-null  bool
#  25  maincat_Shoes                              678530 non-null  bool
#  26  maincat_Handbags & Wallets                 678530 non-null  bool
#  27  maincat_Girls                              678530 non-null  bool
#  28  maincat_Boys                               678530 non-null  bool
#  29  maincat_Shoe, Jewelry & Watch Accessories  678530 non-null  bool
#  30  maincat_Jewelry Accessories                678530 non-null  bool
#  31  maincat_Shoe Care & Accessories            678530 non-null  bool
#  32  maincat_Contemporary & Designer            678530 non-null  bool
#  33  maincat_Travel Accessories                 678530 non-null  bool
#  34  maincat_Surf, Skate & Street               678530 non-null  bool
#  35  subcat_Luggage & Travel Gear               678530 non-null  bool
#  36  subcat_Backpacks                           678530 non-null  bool
#  37  subcat_Novelty & More                      678530 non-null  bool
#  38  subcat_Clothing                            678530 non-null  bool
#  39  subcat_Women                               678530 non-null  bool
#  40  subcat_Baby                                678530 non-null  bool
#  41  subcat_Baby Boys                           678530 non-null  bool
#  42  subcat_Men                                 678530 non-null  bool
#  43  subcat_Maternity                           678530 non-null  bool
#  44  subcat_Baby Girls                          678530 non-null  bool
#  45  subcat_Traditional & Cultural Wear         678530 non-null  bool
#  46  subcat_Accessories                         678530 non-null  bool
#  47  subcat_Jewelry                             678530 non-null  bool
#  48  subcat_Costumes & Accessories              678530 non-null  bool
#  49  subcat_Watches                             678530 non-null  bool
#  50  subcat_Kids & Baby                         678530 non-null  bool
#  51  subcat_Uniforms, Work & Safety             678530 non-null  bool
#  52  subcat_Shoes                               678530 non-null  bool
#  53  subcat_Handbags & Wallets                  678530 non-null  bool
#  54  subcat_Girls                               678530 non-null  bool
#  55  subcat_Boys                                678530 non-null  bool
#  56  subcat_Shoe, Jewelry & Watch Accessories   678530 non-null  bool
#  57  subcat_Jewelry Accessories                 678530 non-null  bool
#  58  subcat_Shoe Care & Accessories             678530 non-null  bool
#  59  subcat_Contemporary & Designer             678530 non-null  bool
#  60  subcat_Travel Accessories                  678530 non-null  bool
#  61  subcat_Surf, Skate & Street                678530 non-null  bool
# dtypes: bool(54), float64(1), int64(1), object(6)
# memory usage: 81.5+ MB

# %% [markdown]
# ## Content Based Recommendation System <a class="anchor" id="content_rec"></a>
#
# Content based recommedation systems use the features of the products to recommend products that are similar. In our this case, most information describing the product are in the description. To quantify the descriptions, a TF-IDF matrix will be used.
#
# TF-IDF stands for term frequency - inverse document frequency, where term frequency is the number of times the word appears in a document and where inverse document frequency looks at how common the word is amongst the corpus.

# %% [markdown]
# ### Example: The Anello Backpack <a class="anchor" id="cosine"></a>
#
# Cosine similarity is a metric used to measure the similarity between two vectors. This similarity is scored between 0 and 1, 1 being the most similar. Let's use the backpack below as an example of how cosine similarity works.

# %%
products_df.loc[products_df['asin'] == '0204444454']
# Out:
#                                             category  \
# 0  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
#
#                                          description  \
# 0  The Hottest Bag in Town! Brand: Anello Conditi...
#
#                                                title   brand     rank  \
# 0  Japan Anello Backpack Unisex PINK BEIGE LARGE ...  Anello  3994472
#
#          asin                                           imageURL  price  \
# 0  0204444454  ['https://images-na.ssl-images-amazon.com/imag...   70.0
#
#    maincat_Luggage & Travel Gear  maincat_Backpacks  ...  subcat_Shoes  \
# 0                           True               True  ...         False
#
#    subcat_Handbags & Wallets  subcat_Girls  subcat_Boys  \
# 0                      False         False        False
#
#    subcat_Shoe, Jewelry & Watch Accessories  subcat_Jewelry Accessories  \
# 0                                     False                       False
#
#    subcat_Shoe Care & Accessories  subcat_Contemporary & Designer  \
# 0                           False                           False
#
#    subcat_Travel Accessories  subcat_Surf, Skate & Street
# 0                      False                        False
#
# [1 rows x 62 columns]

# %% [markdown]
# The TF IDF matrix would be too large to work with, so lets break up the dataframe into the category the item is in.

# %%
products_backpacks = products_df[products_df['maincat_Backpacks'] == True]
products_backpacks
# Out:
#                                                  category  \
# 0       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 1       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 4       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 195     ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 891     ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# ...                                                   ...
# 677184  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 677744  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 677911  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 678252  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 678707  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
#
#                                               description  \
# 0       The Hottest Bag in Town! Brand: Anello Conditi...
# 1       The Hottest Bag in Town! Brand: Anello Conditi...
# 4       2 Way Shoulder Handle Polyester Canvas Boston ...
# 195     Carry your essential items around town in this...
# 891     Yak Pak's most popular backpack, the Student B...
# ...                                                   ...
# 677184  Specifically designed for girls,lovely pattern...
# 677744  Kid's Teenage Mutant Ninja Turtles Out of the ...
# 677911  Withmystyle provide the latest trends and styl...
# 678252  Black & white canvas backpack from Fall Out Bo...
# 678707  Stow and carry your essential gear in style wi...
#
#                                                     title         brand  \
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...        Anello
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...        Anello
# 4       Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...        Anello
# 195                           AmeriLeather Miles Backpack  Amerileather
# 891            Yak Pak 635 Basic Student Backpack - Black       Yak Pak
# ...                                                   ...           ...
# 677184  Dog Pawprint Cat Fingerprint Backpack for Elem...      MIFULGOO
# 677744  Teenage Mutant Ninja Turtles Movie Out of The ...       Unknown
# 677911               Casual Canvas Fashion Shool Backpack       Generic
# 678252            Fall Out Boy Mint Anchor Print Backpack       Unknown
# 678707  18 Inch Student Backpack Bag, Fashion Lightwei...   Trail maker
#
#            rank        asin  \
# 0       3994472  0204444454
# 1        635761  0204444403
# 4       1615335  024444448X
# 195     2990358  B00065EIT8
# 891     4404877  B00080LNUS
# ...         ...         ...
# 677184   155356  B01HGSLJKI
# 677744  2683371  B01HHDG7L8
# 677911  1659770  B01HHNCBH2
# 678252  1584668  B01HIGYDYW
# 678707  2948788  B01HJE5Z7C
#
#                                                  imageURL  price  \
# 0       ['https://images-na.ssl-images-amazon.com/imag...  70.00
# 1       ['https://images-na.ssl-images-amazon.com/imag...  65.99
# 4       ['https://images-na.ssl-images-amazon.com/imag...  65.33
# 195     ['https://images-na.ssl-images-amazon.com/imag...  75.99
# 891     ['https://images-na.ssl-images-amazon.com/imag...  19.52
# ...                                                   ...    ...
# 677184  ['https://images-na.ssl-images-amazon.com/imag...   4.58
# 677744  ['https://images-na.ssl-images-amazon.com/imag...  13.99
# 677911  ['https://images-na.ssl-images-amazon.com/imag...  11.95
# 678252  ['https://images-na.ssl-images-amazon.com/imag...  39.90
# 678707  ['https://images-na.ssl-images-amazon.com/imag...  12.99
#
#         maincat_Luggage & Travel Gear  maincat_Backpacks  ...  subcat_Shoes  \
# 0                                True               True  ...         False
# 1                                True               True  ...         False
# 4                                True               True  ...         False
# 195                              True               True  ...         False
# 891                              True               True  ...         False
# ...                               ...                ...  ...           ...
# 677184                           True               True  ...         False
# 677744                           True               True  ...         False
# 677911                           True               True  ...         False
# 678252                           True               True  ...         False
# 678707                           True               True  ...         False
#
#         subcat_Handbags & Wallets  subcat_Girls  subcat_Boys  \
# 0                           False         False        False
# 1                           False         False        False
# 4                           False         False        False
# 195                         False         False        False
# 891                         False         False        False
# ...                           ...           ...          ...
# 677184                      False         False        False
# 677744                      False         False        False
# 677911                      False         False        False
# 678252                      False         False        False
# 678707                      False         False        False
#
#         subcat_Shoe, Jewelry & Watch Accessories  subcat_Jewelry Accessories  \
# 0                                          False                       False
# 1                                          False                       False
# 4                                          False                       False
# 195                                        False                       False
# 891                                        False                       False
# ...                                          ...                         ...
# 677184                                     False                       False
# 677744                                     False                       False
# 677911                                     False                       False
# 678252                                     False                       False
# 678707                                     False                       False
#
#         subcat_Shoe Care & Accessories  subcat_Contemporary & Designer  \
# 0                                False                           False
# 1                                False                           False
# 4                                False                           False
# 195                              False                           False
# 891                              False                           False
# ...                                ...                             ...
# 677184                           False                           False
# 677744                           False                           False
# 677911                           False                           False
# 678252                           False                           False
# 678707                           False                           False
#
#         subcat_Travel Accessories  subcat_Surf, Skate & Street
# 0                           False                        False
# 1                           False                        False
# 4                           False                        False
# 195                         False                        False
# 891                         False                        False
# ...                           ...                          ...
# 677184                      False                        False
# 677744                      False                        False
# 677911                      False                        False
# 678252                      False                        False
# 678707                      False                        False
#
# [2087 rows x 62 columns]

# %% [markdown]
# Let's look at the other backpacks with the same brand 'Anello'.

# %%
products_backpacks.loc[products_backpacks['brand'] == 'Anello']
# Out:
#                                                  category  \
# 0       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 1       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 4       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 525330  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 616110  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 616112  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 616114  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 620765  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 632262  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 632267  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 632276  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 635377  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 655715  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 655721  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 658761  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 658768  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
#
#                                               description  \
# 0       The Hottest Bag in Town! Brand: Anello Conditi...
# 1       The Hottest Bag in Town! Brand: Anello Conditi...
# 4       2 Way Shoulder Handle Polyester Canvas Boston ...
# 525330  Light and using a durable polyester fabric, ru...
# 616110  Please note there are two deifferent types. 01...
# 616112  The brand Anello means Growth ring in Italian....
# 616114  The brand Anello means Growth ring in Italian....
# 620765  This bag is small size. Please be careful as t...
# 632262  Popular No. 1 product with anello. When openin...
# 632267  Anello is one of the top fashion backpack styl...
# 632276  Popular No. 1 product with anello. When openin...
# 635377  It is a slightly larger backpack using a firm ...
# 655715  A cotton canvas napsack from Anello. There are...
# 655721  A cotton canvas napsack from Anello. There are...
# 658761  Material: polyester capacity: approx 15l openi...
# 658768  Made of Polyester material which is light and ...
#
#                                                     title   brand      rank  \
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...  Anello   3994472
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...  Anello    635761
# 4       Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...  Anello   1615335
# 525330  anello Porikyan capped Luc back zipper AT-B019...  Anello    844054
# 616110  anello #AT-B0197A small casual backpack napsac...  Anello   5382719
# 616112              anello #AT-B1212 backpack cream beige  Anello   5576780
# 616114                    anello #AT-B1212 backpack brown  Anello   6286974
# 620765  anello #AT-B0197B small backpack with side poc...  Anello    377595
# 632262  Anello Official Ruby Red Japan Fashion Shoulde...  Anello    858178
# 632267  Anello Official Blue Japan Fashion Shoulder Ru...  Anello   1392217
# 632276  Anello Official Red Japan Fashion Shoulder Ruc...  Anello   1324725
# 635377  anello Backpack leather die backpack large AT-...  Anello   6956574
# 655715  Anello #ATB0481a Cotton canvas Backpack casual...  Anello   3579036
# 655721  Anello #ATB0481a Cotton canvas Backpack casual...  Anello  10358494
# 658761   ANELLO [100% AUTHENTIC] POLYESTER BACKPACK LARGE  Anello   2027418
# 658768     Anello Polyester Canvas Backpacks Japan import  Anello    139724
#
#               asin                                           imageURL  price  \
# 0       0204444454  ['https://images-na.ssl-images-amazon.com/imag...  70.00
# 1       0204444403  ['https://images-na.ssl-images-amazon.com/imag...  65.99
# 4       024444448X  ['https://images-na.ssl-images-amazon.com/imag...  65.33
# 525330  B016U0OPFY  ['https://images-na.ssl-images-amazon.com/imag...  47.89
# 616110  B01D2MK25U  ['https://images-na.ssl-images-amazon.com/imag...  73.40
# 616112  B01D2MKBUQ  ['https://images-na.ssl-images-amazon.com/imag...  72.99
# 616114  B01D2MKB38  ['https://images-na.ssl-images-amazon.com/imag...  70.49
# 620765  B01DLVYOPG  ['https://images-na.ssl-images-amazon.com/imag...  38.00
# 632262  B01EBI8UH6  ['https://images-na.ssl-images-amazon.com/imag...   9.22
# 632267  B01EBI8XBO  ['https://images-na.ssl-images-amazon.com/imag...   9.22
# 632276  B01EBI8VS4  ['https://images-na.ssl-images-amazon.com/imag...   8.94
# 635377  B01EKQMICW  ['https://images-na.ssl-images-amazon.com/imag...  64.91
# 655715  B01G06T954  ['https://images-na.ssl-images-amazon.com/imag...  84.40
# 655721  B01G06T9CC  ['https://images-na.ssl-images-amazon.com/imag...  93.50
# 658761  B01G7IE3ZQ  ['https://images-na.ssl-images-amazon.com/imag...  59.99
# 658768  B01G7IE40K  ['https://images-na.ssl-images-amazon.com/imag...  60.00
#
#         maincat_Luggage & Travel Gear  maincat_Backpacks  ...  subcat_Shoes  \
# 0                                True               True  ...         False
# 1                                True               True  ...         False
# 4                                True               True  ...         False
# 525330                           True               True  ...         False
# 616110                           True               True  ...         False
# 616112                           True               True  ...         False
# 616114                           True               True  ...         False
# 620765                           True               True  ...         False
# 632262                           True               True  ...         False
# 632267                           True               True  ...         False
# 632276                           True               True  ...         False
# 635377                           True               True  ...         False
# 655715                           True               True  ...         False
# 655721                           True               True  ...         False
# 658761                           True               True  ...         False
# 658768                           True               True  ...         False
#
#         subcat_Handbags & Wallets  subcat_Girls  subcat_Boys  \
# 0                           False         False        False
# 1                           False         False        False
# 4                           False         False        False
# 525330                      False         False        False
# 616110                      False         False        False
# 616112                      False         False        False
# 616114                      False         False        False
# 620765                      False         False        False
# 632262                      False         False        False
# 632267                      False         False        False
# 632276                      False         False        False
# 635377                      False         False        False
# 655715                      False         False        False
# 655721                      False         False        False
# 658761                      False         False        False
# 658768                      False         False        False
#
#         subcat_Shoe, Jewelry & Watch Accessories  subcat_Jewelry Accessories  \
# 0                                          False                       False
# 1                                          False                       False
# 4                                          False                       False
# 525330                                     False                       False
# 616110                                     False                       False
# 616112                                     False                       False
# 616114                                     False                       False
# 620765                                     False                       False
# 632262                                     False                       False
# 632267                                     False                       False
# 632276                                     False                       False
# 635377                                     False                       False
# 655715                                     False                       False
# 655721                                     False                       False
# 658761                                     False                       False
# 658768                                     False                       False
#
#         subcat_Shoe Care & Accessories  subcat_Contemporary & Designer  \
# 0                                False                           False
# 1                                False                           False
# 4                                False                           False
# 525330                           False                           False
# 616110                           False                           False
# 616112                           False                           False
# 616114                           False                           False
# 620765                           False                           False
# 632262                           False                           False
# 632267                           False                           False
# 632276                           False                           False
# 635377                           False                           False
# 655715                           False                           False
# 655721                           False                           False
# 658761                           False                           False
# 658768                           False                           False
#
#         subcat_Travel Accessories  subcat_Surf, Skate & Street
# 0                           False                        False
# 1                           False                        False
# 4                           False                        False
# 525330                      False                        False
# 616110                      False                        False
# 616112                      False                        False
# 616114                      False                        False
# 620765                      False                        False
# 632262                      False                        False
# 632267                      False                        False
# 632276                      False                        False
# 635377                      False                        False
# 655715                      False                        False
# 655721                      False                        False
# 658761                      False                        False
# 658768                      False                        False
#
# [16 rows x 62 columns]

# %% [markdown]
# Now let's start vectorizing using the products_backpacks description column and finding the cosine similarities.

# %%
vectorizer =TfidfVectorizer(stop_words='english', min_df=5, lowercase=True)

TF_IDF_matrix = vectorizer.fit_transform(products_backpacks['description'])

# %%
TF_IDF_matrix.shape
# Out:
# (2087, 2000)

# %%
# Finding the similarities
similarities = cosine_similarity(TF_IDF_matrix, dense_output=False)

# %% [markdown]
# Let's create a dataframe to shows the products and their similarity to the first backpack.

# %%
product_index = products_backpacks[products_backpacks['asin'] == '0204444454'].index

# defining dataframe containing product names and similarities
sim_df = pd.DataFrame(
    {
        'asin': products_backpacks['asin'],
        'product_name': products_backpacks['title'],
        'similarity': np.array(similarities[product_index, :].todense()).squeeze()
    }
)

# %% [markdown]
# Sorting by the highest similarities, we get our original backpack. In the second and third place, other Anello backpacks were recommended, how

# %%
sim_df.sort_values(by='similarity', ascending=False).head(10)
# Out:
#               asin                                       product_name  \
# 0       0204444454  Japan Anello Backpack Unisex PINK BEIGE LARGE ...
# 1       0204444403  Japan Anello Backpack Unisex BLACK LARGE PU LE...
# 4       024444448X  Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...
# 627874  B01E27V99M  Women Girls Ladies Backpack Fashion Shoulder B...
# 205967  B00EME7H5Q  SHENGXILU Women's/Lady's PU Leather Backpack G...
# 472248  B012CHMA2Y  Soft PU Backpack School Bag Travel Bag Frozen ...
# 403536  B00UAD3L6C  Soft PU Backpack Children's School Bag Travel ...
# 405473  B00UHDNKDY  New Fashion Gold /Silver School Travel Gym Sho...
# 252569  B00I49IZSI                      Brixton Men's Carson Backpack
# 388732  B00SWJI3WS        Peppa Pig Large 16" School Backpack(purple)
#
#         similarity
# 0         1.000000
# 1         1.000000
# 4         0.690546
# 627874    0.314537
# 205967    0.254859
# 472248    0.253976
# 403536    0.253976
# 405473    0.252526
# 252569    0.249477
# 388732    0.247832

# %% [markdown]
# ### Creating a General Function <a class="anchor" id="function"></a>
#
# Let's create a function that takes in a product and returns the most similar items in the products dataframe. This function follows a similar flow as the example above.
#
# Some product categories still yield a TF-IDF matrix that is too large, so the dataframe will be sampled from if the number of rows is larger than 10000.

# %%
def content_recommender_cosine(asin):

    '''
    Function that recommends similar item using cosine similarity 

    INPUT: asin (obj) - Unique identifier of product

    OUTPUT: dataframe containing top 10 most similar items
    '''
    # Getting product in dataframe
    product = products_df[products_df['asin'] == asin]

    # Getting index of product in dataframe
    product_index = products_df[products_df['asin'] == asin].index.astype(int)[0]

    ### Making dataframe contain only that category ###

    # Making dataframe containing OHEd main category
    maincat_df = products_df.filter(regex='^maincat_', axis=1)
    
    # Taking the first category as the maincat
    maincat = maincat_df.columns[maincat_df.loc[product_index] == True][0]

    # Making dataframe contain only that category
    maincat_products_df = products_df[products_df[maincat] == True]

    # Resampling if the dataframe is too large
    if maincat_products_df.shape[0] > 10000:

        maincat_products_df = maincat_products_df.sample(n=5000)

        if maincat_products_df.isin([asin]).any().any() == False: 
            
            maincat_products_df = pd.concat([maincat_products_df, product], axis=0)

        else: pass

    else: pass

    # Resetting index
    maincat_products_df = maincat_products_df.reset_index(drop=True)

    # Getting updated products index
    product_index = maincat_products_df[maincat_products_df['asin'] == asin].index.astype(int)[0]

    vectorizer =TfidfVectorizer(stop_words='english', min_df=30, lowercase=True)
    
    TF_IDF_matrix = vectorizer.fit_transform(maincat_products_df['description'])

    similarities = cosine_similarity(TF_IDF_matrix, dense_output=False)

    sim_df = pd.DataFrame(
        {
            'product_name': maincat_products_df['title'],
            'asin': maincat_products_df['asin'],
            'similarity': (np.array(similarities[product_index, :].todense())).squeeze()
        }
    )

    top_products_df = sim_df.sort_values(by='similarity', ascending=False).head(10)

    print(f"Content-based recommendations for '{product.iloc[0]['title']}' in the {maincat.lstrip('maincat_')} category")
    
    return top_products_df

# %% [markdown]
# #### Testing Function
# Let's test out the funtion for various products.

# %%
content_recommender_cosine('024444448X')
# Out:
# Content-based recommendations for 'Japan Anello LARGE CAMO 2 Way Unisex Shoulder Bag Poly Canvas Waterproof Campus' in the Luggage & Travel Gear category
#                                            product_name        asin  \
# 2     Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...  024444448X
# 0     Japan Anello Backpack Unisex PINK BEIGE LARGE ...  0204444454
# 1     Japan Anello Backpack Unisex BLACK LARGE PU LE...  0204444403
# 5224        Anchor Print Drawstring Backpack Sports Bag  B014QDHEAA
# 155              Rothco Nato Canvas Medic Messenger Bag  B000T8ESPG
# 3109       Chevron Print Zig Zag School Travel Backpack  B00KE9BG2I
# 907   Marvel Thor The Mighty Avenger Movie Large Bac...  B004XE33D0
# 1478              ANGRY BIRDS 16" LARGE SCHOOL BACKPACK  B0085GAF2E
# 4053        Peppa Pig Large 16" School Backpack(purple)  B00SWJI3WS
# 5763            Mossy Oak Cotton Canvas Buckle Backpack  B019FXV73G
#
#       similarity
# 2       1.000000
# 0       0.683637
# 1       0.683637
# 5224    0.372056
# 155     0.366854
# 3109    0.347337
# 907     0.346837
# 1478    0.331933
# 4053    0.322385
# 5763    0.318321

# %%
content_recommender_cosine('B004C0TY7E')
# Out:
# Content-based recommendations for 'eBags Shoe Sleeves with Drawstring - For Travel - Set of 2' in the Luggage & Travel Gear category
#                                            product_name        asin  \
# 791   eBags Shoe Sleeves with Drawstring - For Trave...  B004C0TY7E
# 3055  eBags Shoe Sleeves with Drawstring - For Trave...  B00K20EV62
# 218   eBags Shoe Sleeves with Drawstring - For Trave...  B0013KFIXA
# 7012  Travel Shoe Organizer Bags for Boots, High Hee...  B01HB0AZXS
# 845   TUMI - Travel Accessories Shoe Bags - Luggage ...  B004LG4K46
# 7056  Shoe Bag, Bukm Portable Travel Friends Nylon S...  B01HHOIUEY
# 7043  Shoe Bag, Bukm Portable Travel Friends Nylon S...  B01HF2KPF0
# 1334  2 Travel Shoe Bags Luggage Black Bag Golf Suit...  B00756V72M
# 6653  HiDay 4pcs Portable Waterproof Travel Shoe Bag...  B01FA2KROQ
# 6153                  Lewis N. Clark Travel Shoe Covers  B01C4R7PG8
#
#       similarity
# 791     1.000000
# 3055    1.000000
# 218     1.000000
# 7012    0.500866
# 845     0.490664
# 7056    0.477676
# 7043    0.477676
# 1334    0.442499
# 6653    0.434600
# 6153    0.432948

# %% [markdown]
# ## Conclusion <a class="anchor" id="conc"></a>
#
# The content-based recommendation created finds similar products using cosine similarity on the product's TF-IDF matrix made from the description of the product. A general function that does this was created.
#
# *Next Notebook*: `colab_rec.ipynb`
