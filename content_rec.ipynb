# %% [markdown]
# # Content Based Recommendation System

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
products_df = pd.read_csv('Data/products_forvectorizingboolean.csv')

# %%
products_df.duplicated().sum()
# Out:
# 1124

# %%
products_df.drop_duplicates(inplace=True)

# %%
products_df.duplicated().sum()
# Out:
# 0

# %%
products_df.dropna(axis = 0, subset=['description'], inplace=True)

# %%
products_df
# Out:
#                                               description  \
# 0       The Hottest Bag in Town! Brand: Anello Conditi...
# 1       The Hottest Bag in Town! Brand: Anello Conditi...
# 2       Brand New.  Hat Centre Length: adult about 8cm...
# 3       Please allow 1-2cm dimension deviation. 100% b...
# 4       2 Way Shoulder Handle Polyester Canvas Boston ...
# ...                                                   ...
# 680975  Get maximum protection from the elements. Clif...
# 680976  A classic wingtip with a subtle twist that cov...
# 680977  Our classy but sexy strappy sheath cocktail wi...
# 680978  Size Length Hip*2 Age Advice 70 39.5 CM 30 CM ...
# 680979  This classic plain toe style is anything but p...
#
#                                                     title      brand  \
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...     Anello
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...     Anello
# 2       bettyhome Unisex Adult Winter Spring Thicken C...  bettyhome
# 3       bettyhome Womens Lace Short Sleeves Top Printi...  bettyhome
# 4       Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...     Anello
# ...                                                   ...        ...
# 680975             Kaenon Cliff Sunglasses - Select Color     Kaenon
# 680976                    Deer Stags Men's Hampden Oxford    Unknown
# 680977  Laundry by Shelli Segal Women's Fitted Strappy...    Unknown
# 680978  Newborn Baby Girl Bodysuit Lace Floral Romper ...     Hotone
# 680979                       Deer Stags Men's Lohi Oxford    Unknown
#
#               rank        asin   price  maincat_Luggage & Travel Gear  \
# 0        3994472.0  0204444454   70.00                           True
# 1         635761.0  0204444403   65.99                           True
# 2        5061041.0  0206313535   18.99                          False
# 3       10635107.0  0206335962   23.99                          False
# 4        1615335.0  024444448X   65.33                           True
# ...            ...         ...     ...                            ...
# 680975   1908928.0  B01HJH6SA2  199.00                          False
# 680976    956501.0  B01HJH7W0W   52.38                          False
# 680977   3633844.0  B01HJI0G5Y   18.99                          False
# 680978   1671980.0  B01HJHR8A6    4.99                          False
# 680979   1228949.0  B01HJH8JBI   54.12                          False
#
#         maincat_Backpacks  maincat_Novelty & More  maincat_Clothing  ...  \
# 0                    True                   False             False  ...
# 1                    True                   False             False  ...
# 2                   False                    True              True  ...
# 3                   False                   False              True  ...
# 4                    True                   False             False  ...
# ...                   ...                     ...               ...  ...
# 680975              False                   False             False  ...
# 680976              False                   False             False  ...
# 680977              False                   False              True  ...
# 680978              False                   False              True  ...
# 680979              False                   False             False  ...
#
#         subcat_Shoes  subcat_Handbags & Wallets  subcat_Girls  subcat_Boys  \
# 0              False                      False         False        False
# 1              False                      False         False        False
# 2              False                      False         False        False
# 3              False                      False         False        False
# 4              False                      False         False        False
# ...              ...                        ...           ...          ...
# 680975         False                      False         False        False
# 680976          True                      False         False        False
# 680977         False                      False         False        False
# 680978         False                      False         False        False
# 680979          True                      False         False        False
#
#         subcat_Shoe, Jewelry & Watch Accessories  subcat_Jewelry Accessories  \
# 0                                          False                       False
# 1                                          False                       False
# 2                                          False                       False
# 3                                          False                       False
# 4                                          False                       False
# ...                                          ...                         ...
# 680975                                     False                       False
# 680976                                     False                       False
# 680977                                     False                       False
# 680978                                     False                       False
# 680979                                     False                       False
#
#         subcat_Shoe Care & Accessories  subcat_Contemporary & Designer  \
# 0                                False                           False
# 1                                False                           False
# 2                                False                           False
# 3                                False                           False
# 4                                False                           False
# ...                                ...                             ...
# 680975                           False                           False
# 680976                           False                           False
# 680977                           False                           False
# 680978                           False                           False
# 680979                           False                           False
#
#         subcat_Travel Accessories  subcat_Surf, Skate & Street
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# ...                           ...                          ...
# 680975                      False                        False
# 680976                      False                        False
# 680977                      False                        False
# 680978                      False                        False
# 680979                      False                        False
#
# [679654 rows x 60 columns]

# %%
products_df.columns[products_df.columns.str.startswith('maincat_')]
# Out:
# Index(['maincat_Luggage & Travel Gear', 'maincat_Backpacks',
#        'maincat_Novelty & More', 'maincat_Clothing', 'maincat_Women',
#        'maincat_Baby', 'maincat_Baby Boys', 'maincat_Men', 'maincat_Maternity',
#        'maincat_Baby Girls', 'maincat_Traditional & Cultural Wear',
#        'maincat_Accessories', 'maincat_Jewelry',
#        'maincat_Costumes & Accessories', 'maincat_Watches',
#        'maincat_Kids & Baby', 'maincat_Uniforms, Work & Safety',
#        'maincat_Shoes', 'maincat_Handbags & Wallets', 'maincat_Girls',
#        'maincat_Boys', 'maincat_Shoe, Jewelry & Watch Accessories',
#        'maincat_Jewelry Accessories', 'maincat_Shoe Care & Accessories',
#        'maincat_Contemporary & Designer', 'maincat_Travel Accessories',
#        'maincat_Surf, Skate & Street'],
#       dtype='object')

# %% [markdown]
# ## Using Cosine Similarity

# %%
products_df['title'].iloc[0]
# Out:
# 'Japan Anello Backpack Unisex PINK BEIGE LARGE PU LEATHER Rucksack School Bag Campus'

# %% [markdown]
# The TF IDF matrix would be too large to work with, so lets break up the dataframe into categories
# Lets do a test on one category

# %%
products_backpacks = products_df[products_df['maincat_Backpacks'] == True]
products_backpacks
# Out:
#                                               description  \
# 0       The Hottest Bag in Town! Brand: Anello Conditi...
# 1       The Hottest Bag in Town! Brand: Anello Conditi...
# 4       2 Way Shoulder Handle Polyester Canvas Boston ...
# 116     This classic backpack features a unique square...
# 118     Kipling's Alcatraz II is new and improved with...
# ...                                                   ...
# 679432  Specifically designed for girls,lovely pattern...
# 679992  Kid's Teenage Mutant Ninja Turtles Out of the ...
# 680159  Withmystyle provide the latest trends and styl...
# 680500  Black & white canvas backpack from Fall Out Bo...
# 680955  Stow and carry your essential gear in style wi...
#
#                                                     title        brand  \
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...       Anello
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...       Anello
# 4       Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...       Anello
# 116                                 Clava Square Backpack        Clava
# 118           Kipling Alcatraz Ii Wheeled Laptop Backpack      Kipling
# ...                                                   ...          ...
# 679432  Dog Pawprint Cat Fingerprint Backpack for Elem...     MIFULGOO
# 679992  Teenage Mutant Ninja Turtles Movie Out of The ...      Unknown
# 680159               Casual Canvas Fashion Shool Backpack      Generic
# 680500            Fall Out Boy Mint Anchor Print Backpack      Unknown
# 680955  18 Inch Student Backpack Bag, Fashion Lightwei...  Trail maker
#
#               rank        asin  price  maincat_Luggage & Travel Gear  \
# 0        3994472.0  0204444454  70.00                           True
# 1         635761.0  0204444403  65.99                           True
# 4        1615335.0  024444448X  65.33                           True
# 116     13753935.0  B000078ORA  96.99                           True
# 118      2069453.0  B000078QUR  21.41                           True
# ...            ...         ...    ...                            ...
# 679432    155356.0  B01HGSLJKI   4.58                           True
# 679992   2683371.0  B01HHDG7L8  13.99                           True
# 680159   1659770.0  B01HHNCBH2  11.95                           True
# 680500   1584668.0  B01HIGYDYW  39.90                           True
# 680955   2948788.0  B01HJE5Z7C  12.99                           True
#
#         maincat_Backpacks  maincat_Novelty & More  maincat_Clothing  ...  \
# 0                    True                   False             False  ...
# 1                    True                   False             False  ...
# 4                    True                   False             False  ...
# 116                  True                   False             False  ...
# 118                  True                   False             False  ...
# ...                   ...                     ...               ...  ...
# 679432               True                   False             False  ...
# 679992               True                   False             False  ...
# 680159               True                   False             False  ...
# 680500               True                   False             False  ...
# 680955               True                   False             False  ...
#
#         subcat_Shoes  subcat_Handbags & Wallets  subcat_Girls  subcat_Boys  \
# 0              False                      False         False        False
# 1              False                      False         False        False
# 4              False                      False         False        False
# 116            False                      False         False        False
# 118            False                      False         False        False
# ...              ...                        ...           ...          ...
# 679432         False                      False         False        False
# 679992         False                      False         False        False
# 680159         False                      False         False        False
# 680500         False                      False         False        False
# 680955         False                      False         False        False
#
#         subcat_Shoe, Jewelry & Watch Accessories  subcat_Jewelry Accessories  \
# 0                                          False                       False
# 1                                          False                       False
# 4                                          False                       False
# 116                                        False                       False
# 118                                        False                       False
# ...                                          ...                         ...
# 679432                                     False                       False
# 679992                                     False                       False
# 680159                                     False                       False
# 680500                                     False                       False
# 680955                                     False                       False
#
#         subcat_Shoe Care & Accessories  subcat_Contemporary & Designer  \
# 0                                False                           False
# 1                                False                           False
# 4                                False                           False
# 116                              False                           False
# 118                              False                           False
# ...                                ...                             ...
# 679432                           False                           False
# 679992                           False                           False
# 680159                           False                           False
# 680500                           False                           False
# 680955                           False                           False
#
#         subcat_Travel Accessories  subcat_Surf, Skate & Street
# 0                           False                        False
# 1                           False                        False
# 4                           False                        False
# 116                         False                        False
# 118                         False                        False
# ...                           ...                          ...
# 679432                      False                        False
# 679992                      False                        False
# 680159                      False                        False
# 680500                      False                        False
# 680955                      False                        False
#
# [2089 rows x 60 columns]

# %%
vectorizer =TfidfVectorizer(stop_words='english', min_df=5, lowercase=True)

TF_IDF_matrix = vectorizer.fit_transform(products_backpacks['description'])

# %%
TF_IDF_matrix.shape
# Out:
# (2089, 2001)

# %%
similarities = cosine_similarity(TF_IDF_matrix, dense_output=False)

# %%
product_index = products_backpacks\
    [products_backpacks['title'] == 'Japan Anello Backpack Unisex PINK BEIGE LARGE PU LEATHER Rucksack School Bag Campus']\
    .index

sim_df = pd.DataFrame(
    {
        'product_name': products_backpacks['title'],
        'similarity': np.array(similarities[product_index, :].todense()).squeeze()
    }
)

# %%
sim_df.sort_values(by='similarity', ascending=False).head(10)
# Out:
#                                              product_name  similarity
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...    1.000000
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...    1.000000
# 4       Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...    0.690685
# 630122  Women Girls Ladies Backpack Fashion Shoulder B...    0.314540
# 208215  SHENGXILU Women's/Lady's PU Leather Backpack G...    0.254706
# 474496  Soft PU Backpack School Bag Travel Bag Frozen ...    0.253860
# 405784  Soft PU Backpack Children's School Bag Travel ...    0.253860
# 407721  New Fashion Gold /Silver School Travel Gym Sho...    0.252468
# 254817                      Brixton Men's Carson Backpack    0.249343
# 390980        Peppa Pig Large 16" School Backpack(purple)    0.247869

# %%
products_df['title'].loc[407721]
# Out:
# 'New Fashion Gold /Silver School Travel Gym Shoulder Bag Backpack'

# %% [markdown]
# ---

# %%
products_women = products_df[products_df['maincat_Women'] == True]
products_women
# Out:
#                                               description  \
# 2       Brand New.  Hat Centre Length: adult about 8cm...
# 3       Please allow 1-2cm dimension deviation. 100% b...
# 13      Veneziana Sexy Strip 20 Open Crotch Pantyhose ...
# 14      Veneziana Ar Beautiful - Hold Ups Thigh High S...
# 15      Snug ribbed knit. Size One Size. Fabric 100% S...
# ...                                                   ...
# 680969  HONGYE : Best Jewelry Choice You Could Never M...
# 680970  Dance along the trail with nimble agility in t...
# 680971  Show your Nor Cal spirit with our limited edit...
# 680974  Funny Tshirts For, Funny Birthday Gift Tshirts...
# 680977  Our classy but sexy strappy sheath cocktail wi...
#
#                                                     title             brand  \
# 2       bettyhome Unisex Adult Winter Spring Thicken C...         bettyhome
# 3       bettyhome Womens Lace Short Sleeves Top Printi...         bettyhome
# 13                                              Sexystrip         Veneziana
# 14                                              Beautiful         Veneziana
# 15      Beechfield Ladies/Womens Metro Knitted Winter ...        Beechfield
# ...                                                   ...               ...
# 680969  HONGYE Fashion Three-dimensional Love Heart Ne...            HONGYE
# 680970  HOKA ONE ONE Women's Speed Instinct Trail Runn...      HOKA ONE ONE
# 680971     Nor Cal T-Shirt - STRAIGHT OUTTA NOR CAL Shirt           Unknown
# 680974  Sysadmin Because Even Developer Need Heroes T-...  Sysadmin t shirt
# 680977  Laundry by Shelli Segal Women's Fitted Strappy...           Unknown
#
#               rank        asin   price  maincat_Luggage & Travel Gear  \
# 2        5061041.0  0206313535   18.99                          False
# 3       10635107.0  0206335962   23.99                          False
# 13        734888.0  5120053017   14.95                          False
# 14        551160.0  5120053351   17.70                          False
# 15       6396025.0  5120192157   29.29                          False
# ...            ...         ...     ...                            ...
# 680969    528223.0  B01HJGJ512   16.99                          False
# 680970    915676.0  B01HJFMJQQ  144.48                          False
# 680971   1801862.0  B01HJGV808   17.99                          False
# 680974   2596846.0  B01HJHLSR0   18.88                          False
# 680977   3633844.0  B01HJI0G5Y   18.99                          False
#
#         maincat_Backpacks  maincat_Novelty & More  maincat_Clothing  ...  \
# 2                   False                    True              True  ...
# 3                   False                   False              True  ...
# 13                  False                   False             False  ...
# 14                  False                   False             False  ...
# 15                  False                    True              True  ...
# ...                   ...                     ...               ...  ...
# 680969              False                   False             False  ...
# 680970              False                   False             False  ...
# 680971              False                    True              True  ...
# 680974              False                    True              True  ...
# 680977              False                   False              True  ...
#
#         subcat_Shoes  subcat_Handbags & Wallets  subcat_Girls  subcat_Boys  \
# 2              False                      False         False        False
# 3              False                      False         False        False
# 13             False                      False         False        False
# 14             False                      False         False        False
# 15             False                      False         False        False
# ...              ...                        ...           ...          ...
# 680969         False                      False         False        False
# 680970          True                      False         False        False
# 680971         False                      False         False        False
# 680974         False                      False         False        False
# 680977         False                      False         False        False
#
#         subcat_Shoe, Jewelry & Watch Accessories  subcat_Jewelry Accessories  \
# 2                                          False                       False
# 3                                          False                       False
# 13                                         False                       False
# 14                                         False                       False
# 15                                         False                       False
# ...                                          ...                         ...
# 680969                                     False                       False
# 680970                                     False                       False
# 680971                                     False                       False
# 680974                                     False                       False
# 680977                                     False                       False
#
#         subcat_Shoe Care & Accessories  subcat_Contemporary & Designer  \
# 2                                False                           False
# 3                                False                           False
# 13                               False                           False
# 14                               False                           False
# 15                               False                           False
# ...                                ...                             ...
# 680969                           False                           False
# 680970                           False                           False
# 680971                           False                           False
# 680974                           False                           False
# 680977                           False                           False
#
#         subcat_Travel Accessories  subcat_Surf, Skate & Street
# 2                           False                        False
# 3                           False                        False
# 13                          False                        False
# 14                          False                        False
# 15                          False                        False
# ...                           ...                          ...
# 680969                      False                        False
# 680970                      False                        False
# 680971                      False                        False
# 680974                      False                        False
# 680977                      False                        False
#
# [354210 rows x 60 columns]

# %%
products_women_sample = products_women.sample(n=10000, random_state=42)
products_women_sample = products_women_sample.reset_index()
products_women_sample
# Out:
#        index                                        description  \
# 0      11670  HONDA is a trademark of Honda Motor Co., Ltd. ...
# 1     611472  Beautiful ankle wrap bootie with a zip closure...
# 2     474110  Brass With Yellow Finish Police Officer Charm ...
# 3     380012  Denim Jacket, Denim Jacket, Machine Wash Cold ...
# 4     647922  Haase Unlimited Women\'s T-shirts are great fo...
# ...      ...                                                ...
# 9995  218569  This stylish city sandal features a laser cut ...
# 9996   88540  Made of the finest materials available. Manufa...
# 9997  282535  Black and white never go out of style, and we ...
# 9998  630659  Every girl is on a quest for the perfect dress...
# 9999    8370  Rubie's costume company has the licensed and n...
#
#                                                   title  \
# 0     Honda Flame Fine Embroidered Hat Cap, Black/Si...
# 1                 Not Rated Women's Odessa Chelsea Boot
# 2     Angelica Collection Yellow Brass Police Office...
# 3                                  Women's Denim Jacket
# 4     HAASE UNLIMITED Women's Goodbye Tension, Hello...
# ...                                                 ...
# 9995  Carlos by Carlos Santana Women's Dynamic Dress...
# 9996  H&M Christian Jewelry 1 1/16 Inch Sterling Sil...
# 9997  VIRGIN ONLY Women's Geometric Black Velvet Pri...
# 9998                Extravagant Long Maxi Daywear Dress
# 9999  Rubie's Costume Co Men's Superman Returns Delu...
#
#                          brand        rank        asin  price  \
# 0                  A&E Designs   4519868.0  B000NN8TTI  21.99
# 1                    Not Rated    834684.0  B01COQNDJM  28.97
# 2          Angelica Collection   5168500.0  B012BCSB2I  18.98
# 3                      Noble U   3329121.0  B00RNG80EC  85.00
# 4              HAASE UNLIMITED   7877148.0  B01F9JP27W  13.92
# ...                        ...         ...         ...    ...
# 9995  Carlos by Carlos Santana   3411569.0  B00FEM6DCI  59.99
# 9996                       H&M   9020971.0  B005IGZP3I  48.40
# 9997               VIRGIN ONLY   3852502.0  B00JZFNSLO  14.99
# 9998                   Aakasha  10650824.0  B01E40OKR0  79.00
# 9999                   Unknown   8843351.0  B000HAPLHA  12.25
#
#       maincat_Luggage & Travel Gear  maincat_Backpacks  \
# 0                             False              False
# 1                             False              False
# 2                             False              False
# 3                             False              False
# 4                             False              False
# ...                             ...                ...
# 9995                          False              False
# 9996                          False              False
# 9997                          False              False
# 9998                          False              False
# 9999                          False              False
#
#       maincat_Novelty & More  ...  subcat_Shoes  subcat_Handbags & Wallets  \
# 0                       True  ...         False                      False
# 1                      False  ...          True                      False
# 2                      False  ...         False                      False
# 3                      False  ...         False                      False
# 4                       True  ...         False                      False
# ...                      ...  ...           ...                        ...
# 9995                   False  ...          True                      False
# 9996                   False  ...         False                      False
# 9997                   False  ...         False                      False
# 9998                   False  ...         False                      False
# 9999                   False  ...         False                      False
#
#       subcat_Girls  subcat_Boys  subcat_Shoe, Jewelry & Watch Accessories  \
# 0            False        False                                     False
# 1            False        False                                     False
# 2            False        False                                     False
# 3            False        False                                     False
# 4            False        False                                     False
# ...            ...          ...                                       ...
# 9995         False        False                                     False
# 9996         False        False                                     False
# 9997         False        False                                     False
# 9998         False        False                                     False
# 9999         False        False                                     False
#
#       subcat_Jewelry Accessories  subcat_Shoe Care & Accessories  \
# 0                          False                           False
# 1                          False                           False
# 2                          False                           False
# 3                          False                           False
# 4                          False                           False
# ...                          ...                             ...
# 9995                       False                           False
# 9996                       False                           False
# 9997                       False                           False
# 9998                       False                           False
# 9999                       False                           False
#
#       subcat_Contemporary & Designer  subcat_Travel Accessories  \
# 0                              False                      False
# 1                              False                      False
# 2                              False                      False
# 3                              False                      False
# 4                              False                      False
# ...                              ...                        ...
# 9995                           False                      False
# 9996                           False                      False
# 9997                           False                      False
# 9998                           False                      False
# 9999                           False                      False
#
#       subcat_Surf, Skate & Street
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 9995                        False
# 9996                        False
# 9997                        False
# 9998                        False
# 9999                        False
#
# [10000 rows x 61 columns]

# %%
products_women_sample['title'].iloc[9995]
# Out:
# "Carlos by Carlos Santana Women's Dynamic Dress Sandal"

# %%
vectorizer =TfidfVectorizer(stop_words='english', min_df=5, lowercase=True)

TF_IDF_matrix = vectorizer.fit_transform(products_women_sample['description'])

# %%
TF_IDF_matrix.shape
# Out:
# (10000, 7155)

# %%
similarities = cosine_similarity(TF_IDF_matrix, dense_output=False)

# %%
product_index = products_women_sample[products_women_sample['title'] == "Carlos by Carlos Santana Women's Dynamic Dress Sandal"].index

sim_df = pd.DataFrame(
    {
        'product_name': products_women_sample['title'],
        'similarity': np.array(similarities[product_index, :].todense()).squeeze()
    }
)

# %%
sim_df.sort_values(by='similarity', ascending=False).head(10)
# Out:
#                                            product_name  similarity
# 9995  Carlos by Carlos Santana Women's Dynamic Dress...    1.000000
# 71             Carlos by Carlos Santana Women's Melinda    0.975294
# 3587  Carlos by Carlos Santana Women's Kaliopi Ankle...    0.970268
# 5838  Carlos by Carlos Santana Women's Maiko Wedge S...    0.953800
# 7089  Carlos by Carlos Santana Women's Kiara Gladiat...    0.890211
# 3957  Carlos by Carlos Santana Womens Zadie Almond T...    0.522622
# 7884              Santana Women's Brenna Knee-High Boot    0.247555
# 9005  Endangered Natural Sapphire w/ruby eyes frog b...    0.197982
# 9078  FLY London Women's Ydel Perf Wedge Pump,Beige/...    0.110600
# 123   Full Zip Fleece Jacket with Pink Ribbon Embroi...    0.099564

# %%
products_df['title'].loc[407721]
# Out:
# 'New Fashion Gold /Silver School Travel Gym Shoulder Bag Backpack'

# %% [markdown]
# ### Creating a General Function

# %%
def content_recommender_cosine(title, products, category):

    products = products[products[category] == True]

    if products.shape[0] > 10000:

        products = products.sample(n=10000, random_state=42)

        products = products.reset_index()

    else: pass

    vectorizer =TfidfVectorizer(stop_words='english', min_df=30, lowercase=True)
    
    TF_IDF_matrix = vectorizer.fit_transform(products['description'])

    similarities = cosine_similarity(TF_IDF_matrix, dense_output=False)

    product_index = products[products['title'] == title].index

    sim_df = pd.DataFrame(
        {
            'product_name': products['title'],
            'similarity': np.array(similarities[product_index, :].todense()).squeeze(),
        }
    )

    top_products = sim_df.sort_values(by='similarity', ascending=False).head(10)

    return top_products

# %%
content_recommender_cosine('Japan Anello Backpack Unisex PINK BEIGE LARGE PU LEATHER Rucksack School Bag Campus', 
                            products_df, 'maincat_Backpacks')
# Out:
#                                              product_name  similarity
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...    1.000000
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...    1.000000
# 4       Japan Anello LARGE CAMO 2 Way Unisex Shoulder ...    0.678002
# 630122  Women Girls Ladies Backpack Fashion Shoulder B...    0.458001
# 208215  SHENGXILU Women's/Lady's PU Leather Backpack G...    0.437090
# 254817                      Brixton Men's Carson Backpack    0.392878
# 474496  Soft PU Backpack School Bag Travel Bag Frozen ...    0.382243
# 405784  Soft PU Backpack Children's School Bag Travel ...    0.382243
# 433616  Remeehi Girl's Sliver Holographic Laser School...    0.355488
# 293572  Le Donne Leather Distressed Leather Multi Pock...    0.335467
