# %% [markdown]
# # Recommendation System for Amazon Clothing Products
# ---
# ## 4. Content Based Recommendation System
#
# *Author*: Mariam Elsayed
#
# *Contact*: mariamkelsayed@gmail.com
#
# *Notebook*: 4 of 5
#
# *Previous Notebook*: `popularity_rec.ipynb`
#
# *Next Notebook*: `colab_rec.ipynb`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Table of Contents
#
# * [Introduction](#intro)
#
# * [Loading the Data](#loading)
#
# * [Content Based Recommendation System](#rec)
#
#     * [Using Cosine Similarity](#cosine)
#
#     * [Creating a General Function](#function)
#
# * [Conclusion](#conc)

# %% [markdown]
# ## Introduction <a class="anchor" id="intro"></a>
#
# Next let's create a content based recommendation system. This would rely on ranking how similar different products are based on their description.

# %% [markdown]
# ## Loading the Data <a class="anchor" id="loading"></a>
#
# This recommendation system will use the products data created in the preprocessing notebooks.

# %%
# Reading the data
products_df = pd.read_csv('Data/products_summary.csv')

# %%
products_df
# Out:
#                                                  category  \
# 0       ['Clothing, Shoes & Jewelry', 'Women', 'Import...
# 1       ['Clothing, Shoes & Jewelry', 'Women', 'Import...
# 2       ['Clothing, Shoes & Jewelry', 'Women', 'Matern...
# 3       ['Clothing, Shoes & Jewelry', 'Baby', 'Baby Gi...
# 4       ['Clothing, Shoes & Jewelry', 'Women', 'Clothi...
# ...                                                   ...
# 147467  ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', ...
# 147468  ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', ...
# 147469  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 147470  ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', ...
# 147471  ['Clothing, Shoes & Jewelry', 'Baby', 'Baby Gi...
#
#                                               description  \
# 0       Veneziana Sexy Strip 20 Open Crotch Pantyhose ...
# 1       Veneziana Ar Beautiful - Hold Ups Thigh High S...
# 2       Dress Length (Neck to Bottom Hem) Small - 40 i...
# 3       Little Brother: Size 70: Length 38 CM, Bust*2 ...
# 4       GorgeoUS lightweight cotton dress in red, pink...
# ...                                                   ...
# 147467  These men's Tubular shoes honor running-inspir...
# 147468  An edgy take on Adidas running-inspired herita...
# 147469  Catalina - where sporty meets sparkly! adorned...
# 147470  A classic wingtip with a subtle twist that cov...
# 147471  Size Length Hip*2 Age Advice 70 39.5 CM 30 CM ...
#
#                                                     title      brand     rank  \
# 0                                               Sexystrip  Veneziana   734888
# 1                                               Beautiful  Veneziana   551160
# 2       sofsy Soft-Touch Rayon Blend Tie Front Nursing...    Unknown   740957
# 3       Toddler Girls Big Sister T Shirt Matching Litt...     Kingte    36991
# 4       Pistachio Women's Sun Flower Flowing Knee Leng...  Pistachio  1131061
# ...                                                   ...        ...      ...
# 147467  adidas Originals Men's Tubular Shadow Running ...    Unknown    20519
# 147468  adidas Originals Men's Tubular Shadow Fashion ...    Unknown    74828
# 147469                Dansko Women's Catalina Flat Sandal    Unknown  1114685
# 147470                    Deer Stags Men's Hampden Oxford    Unknown   956501
# 147471  Newborn Baby Girl Bodysuit Lace Floral Romper ...     Hotone  1671980
#
#               asin                                           imageURL   price  \
# 0       5120053017  ['https://images-na.ssl-images-amazon.com/imag...   14.95
# 1       5120053351  ['https://images-na.ssl-images-amazon.com/imag...   17.70
# 2       5120053890  ['https://images-na.ssl-images-amazon.com/imag...   34.99
# 3       5780122040  ['https://images-na.ssl-images-amazon.com/imag...   10.49
# 4       6040972467  ['https://images-na.ssl-images-amazon.com/imag...   22.99
# ...            ...                                                ...     ...
# 147467  B01HJDW6ZC  ['https://images-na.ssl-images-amazon.com/imag...  120.08
# 147468  B01HJDVCJI  ['https://images-na.ssl-images-amazon.com/imag...  123.72
# 147469  B01HJCMR4I  ['https://images-na.ssl-images-amazon.com/imag...   94.98
# 147470  B01HJH7W0W  ['https://images-na.ssl-images-amazon.com/imag...   52.38
# 147471  B01HJHR8A6  ['https://images-na.ssl-images-amazon.com/imag...    4.99
#
#         maincat_Luggage & Travel Gear  maincat_Backpacks  ...  subcat_Girls  \
# 0                               False              False  ...         False
# 1                               False              False  ...         False
# 2                               False              False  ...         False
# 3                               False              False  ...         False
# 4                               False              False  ...         False
# ...                               ...                ...  ...           ...
# 147467                          False              False  ...         False
# 147468                          False              False  ...         False
# 147469                          False              False  ...         False
# 147470                          False              False  ...         False
# 147471                          False              False  ...         False
#
#         subcat_Boys  subcat_Shoe, Jewelry & Watch Accessories  \
# 0             False                                     False
# 1             False                                     False
# 2             False                                     False
# 3             False                                     False
# 4             False                                     False
# ...             ...                                       ...
# 147467        False                                     False
# 147468        False                                     False
# 147469        False                                     False
# 147470        False                                     False
# 147471        False                                     False
#
#         subcat_Jewelry Accessories  subcat_Shoe Care & Accessories  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ...                            ...                             ...
# 147467                       False                           False
# 147468                       False                           False
# 147469                       False                           False
# 147470                       False                           False
# 147471                       False                           False
#
#         subcat_Contemporary & Designer  subcat_Travel Accessories  \
# 0                                False                      False
# 1                                False                      False
# 2                                False                      False
# 3                                False                      False
# 4                                False                      False
# ...                                ...                        ...
# 147467                           False                      False
# 147468                           False                      False
# 147469                           False                      False
# 147470                           False                      False
# 147471                           False                      False
#
#         subcat_Surf, Skate & Street  average_rating  total_reviews
# 0                             False             3.7             38
# 1                             False             3.9             47
# 2                             False             4.6             31
# 3                             False             3.5              6
# 4                             False             4.2             26
# ...                             ...             ...            ...
# 147467                        False             4.9              8
# 147468                        False             5.0              3
# 147469                        False             4.1             15
# 147470                        False             4.0              5
# 147471                        False             4.2             11
#
# [147472 rows x 64 columns]

# %%
products_df['title'].loc[3000]
# Out:
# 'Hoodie: Batman - Logo Pullover Hoodie Size M'

# %%
products_df = products_df.dropna(axis=0)

# %% [markdown]
# ## Content Based Recommendation System <a class="anchor" id="content_rec"></a>
#
# Content based recommedation systems use the features of the products to recommend products that are similar. In our this case, most information describing the product are in the description. To quantify the descriptions, a TF-IDF matrix will be used.
#
# TF-IDF stands for term frequency - inverse document frequency, where term frequency is the number of times the word appears in a document and where inverse document frequency looks at how common the word is amongst the corpus.

# %% [markdown]
# ### Using Cosine Similarity <a class="anchor" id="cosine"></a>
#
# Cosine similarity is a metric used to measure the similarity between two vectors. This similarity is scored between 0 and 1, 1 being the most similar. Let's use the backpack below as an example of how cosine similarity works.

# %%
products_df['title'].loc['asin' = '0204444454']
# Out:
# 'Sexystrip'

# %% [markdown]
# The TF IDF matrix would be too large to work with, so lets break up the dataframe into the category the item is in.

# %%
products_backpacks = products_df[products_df['maincat_Backpacks'] == True]
products_backpacks
# Out:
#                                                  category  \
# 0       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 1       ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 146     ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 698     ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 838     ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# ...                                                   ...
# 474165  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 474174  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 474564  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 474695  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
# 474904  ['Clothing, Shoes & Jewelry', 'Luggage & Trave...
#
#                                               description  \
# 0       The Hottest Bag in Town! Brand: Anello Conditi...
# 1       The Hottest Bag in Town! Brand: Anello Conditi...
# 146     Carry your essential items around town in this...
# 698     Yak Pak's most popular backpack, the Student B...
# 838     Osgoode Marley knows that backpacks remain a s...
# ...                                                   ...
# 474165  This cute and fashionable Disney Little Mermai...
# 474174  Specifically designed for girls,lovely pattern...
# 474564  Kid's Teenage Mutant Ninja Turtles Out of the ...
# 474695  Withmystyle provide the latest trends and styl...
# 474904  Black & white canvas backpack from Fall Out Bo...
#
#                                                     title           brand  \
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...          Anello
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...          Anello
# 146                           AmeriLeather Miles Backpack    Amerileather
# 698            Yak Pak 635 Basic Student Backpack - Black         Yak Pak
# 838      Osgoode Marley Cashmere Large Organizer Backpack  Osgoode Marley
# ...                                                   ...             ...
# 474165  Disney Girl's The Little Mermaid Ariel 16" Sch...         Unknown
# 474174  Dog Pawprint Cat Fingerprint Backpack for Elem...        MIFULGOO
# 474564  Teenage Mutant Ninja Turtles Movie Out of The ...         Unknown
# 474695               Casual Canvas Fashion Shool Backpack         Generic
# 474904            Fall Out Boy Mint Anchor Print Backpack         Unknown
#
#            rank        asin  price  maincat_Luggage & Travel Gear  \
# 0       3994472  0204444454  70.00                           True
# 1        635761  0204444403  65.99                           True
# 146     2990358  B00065EIT8  75.99                           True
# 698     4404877  B00080LNUS  19.52                           True
# 838      493947  B00097DYSE  14.20                           True
# ...         ...         ...    ...                            ...
# 474165  2059273  B01HGS2876   6.58                           True
# 474174   155356  B01HGSLJKI   4.58                           True
# 474564  2683371  B01HHDG7L8  13.99                           True
# 474695  1659770  B01HHNCBH2  11.95                           True
# 474904  1584668  B01HIGYDYW  39.90                           True
#
#         maincat_Backpacks  maincat_Novelty & More  ...  subcat_Girls  \
# 0                    True                   False  ...         False
# 1                    True                   False  ...         False
# 146                  True                   False  ...         False
# 698                  True                   False  ...         False
# 838                  True                   False  ...         False
# ...                   ...                     ...  ...           ...
# 474165               True                   False  ...         False
# 474174               True                   False  ...         False
# 474564               True                   False  ...         False
# 474695               True                   False  ...         False
# 474904               True                   False  ...         False
#
#         subcat_Boys  subcat_Shoe, Jewelry & Watch Accessories  \
# 0             False                                     False
# 1             False                                     False
# 146           False                                     False
# 698           False                                     False
# 838           False                                     False
# ...             ...                                       ...
# 474165        False                                     False
# 474174        False                                     False
# 474564        False                                     False
# 474695        False                                     False
# 474904        False                                     False
#
#         subcat_Jewelry Accessories  subcat_Shoe Care & Accessories  \
# 0                            False                           False
# 1                            False                           False
# 146                          False                           False
# 698                          False                           False
# 838                          False                           False
# ...                            ...                             ...
# 474165                       False                           False
# 474174                       False                           False
# 474564                       False                           False
# 474695                       False                           False
# 474904                       False                           False
#
#         subcat_Contemporary & Designer  subcat_Travel Accessories  \
# 0                                False                      False
# 1                                False                      False
# 146                              False                      False
# 698                              False                      False
# 838                              False                      False
# ...                                ...                        ...
# 474165                           False                      False
# 474174                           False                      False
# 474564                           False                      False
# 474695                           False                      False
# 474904                           False                      False
#
#         subcat_Surf, Skate & Street  average_rating  total_reviews
# 0                             False             4.5              2
# 1                             False             5.0              2
# 146                           False             4.5              4
# 698                           False             5.0              1
# 838                           False             5.0             10
# ...                             ...             ...            ...
# 474165                        False             5.0              1
# 474174                        False             4.7             40
# 474564                        False             5.0              1
# 474695                        False             5.0              3
# 474904                        False             4.0              5
#
# [1538 rows x 63 columns]

# %% [markdown]
# Now let's start vectorizing using the products_backpacks description column and finding the cosine similarities.

# %%
vectorizer =TfidfVectorizer(stop_words='english', min_df=5, lowercase=True)

TF_IDF_matrix = vectorizer.fit_transform(products_backpacks['description'])

# %%
TF_IDF_matrix.shape
# Out:
# (1538, 1663)

# %%
# Finding the similarities
similarities = cosine_similarity(TF_IDF_matrix, dense_output=False)

# %% [markdown]
# Let's create a dataframe to shows the products and their similarity to the first backpack.

# %%
product_index = products_backpacks\
    [products_backpacks['title'] == 'Japan Anello Backpack Unisex PINK BEIGE LARGE PU LEATHER Rucksack School Bag Campus']\
    .index

# defining dataframe containing product names and similarities
sim_df = pd.DataFrame(
    {
        'product_name': products_backpacks['title'],
        'similarity': np.array(similarities[product_index, :].todense()).squeeze()
    }
)

# %% [markdown]
# Sorting by the highest similarities, we get our original backpack. In the second and third place, the brands other backpacks appear.

# %%
sim_df.sort_values(by='similarity', ascending=False).head(10)
# Out:
#                                              product_name  similarity
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...    1.000000
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...    1.000000
# 440185  Women Girls Ladies Backpack Fashion Shoulder B...    0.331545
# 286031  New Fashion Gold /Silver School Travel Gym Sho...    0.270979
# 451082  Handolederco Vintage Bag Leather Handmade Vint...    0.255005
# 274420        Peppa Pig Large 16" School Backpack(purple)    0.252894
# 286519  Donalworld Women Sequin Backpack Bling Paillet...    0.250486
# 238514    AmeriBag Small Classic Leather Healthy Back Bag    0.245286
# 88002               ANGRY BIRDS 16" LARGE SCHOOL BACKPACK    0.227965
# 28794            Leatherbay Leather Backpack with Pockets    0.226652

# %% [markdown]
# ### Creating a General Function <a class="anchor" id="function"></a>
#
# Let's create a function that takes in a product and returns the most similar items in the products dataframe. Some product categories still yield a TF-IDF matrix that is too large, so the dataframe will be sampled from if the number of rows is larger than 10000.

# %%
def content_recommender_cosine(title, products, category):

    '''
    Function that recommends similar item using cosine similarity 

    INPUT: title (str) - Name of product
           products (df) - Dataframe containing product
           category (str) - Category of the product

    OUTPUT: dataframe containing top 10 most similar items
    '''
    # Making dataframe contain only that category
    products = products[products[category] == True]

    # Defining the input product 
    product = products[products['title'] == title]

    # Resampling if the dataframe is too large
    if products.shape[0] > 10000:

        products = products.sample(n=500).reset_index()

        products = pd.concat([products, product], axis=0)

        products = products.reset_index()

    else: pass

    vectorizer =TfidfVectorizer(stop_words='english', min_df=30, lowercase=True)
    
    TF_IDF_matrix = vectorizer.fit_transform(products['description'])

    similarities = cosine_similarity(TF_IDF_matrix, dense_output=False)

    product_index = products[products['title'] == title].index

    sim_df = pd.DataFrame(
        {
            'product_name': products['title'],
            'asin': products['asin'],
            'similarity': (np.array(similarities[product_index, :].todense())).squeeze()
        }
    )

    top_products = sim_df.sort_values(by='similarity', ascending=False).head(10)

    return top_products

# %%
content_recommender_cosine('Japan Anello Backpack Unisex PINK BEIGE LARGE PU LEATHER Rucksack School Bag Campus', 
                            products_df, 'maincat_Backpacks')
# Out:
#                                              product_name        asin  \
# 0       Japan Anello Backpack Unisex PINK BEIGE LARGE ...  0204444454
# 1       Japan Anello Backpack Unisex BLACK LARGE PU LE...  0204444403
# 440185  Women Girls Ladies Backpack Fashion Shoulder B...  B01E27V99M
# 415526  Goson Genuine Leather Mini Backpack Handbag/Pu...  B01BL4C5HO
# 323015  Batman Acrylic Logo Faux Leather Backpack [App...  B010JAK5NW
# 227391                         Floto Toscana Leather Pack  B00MOX5ZRE
# 286519  Donalworld Women Sequin Backpack Bling Paillet...  B00UJK8IG4
# 238514    AmeriBag Small Classic Leather Healthy Back Bag  B00NUGHNME
# 432518           Harvest Label Urban Rolltop Backpack 2.0  B01D3RC9QE
# 147255  Saddleback Leather Co. Full Grain Leather Back...  B00EK25RPM
#
#         similarity
# 0         1.000000
# 1         1.000000
# 440185    0.494976
# 415526    0.371702
# 323015    0.345792
# 227391    0.332771
# 286519    0.329615
# 238514    0.325498
# 432518    0.325080
# 147255    0.322914

# %%
content_recommender_cosine("Deer Stags Men's Hampden Oxford", products_df, 'maincat_Shoes')
# Out:
#                                           product_name        asin  similarity
# 500                    Deer Stags Men's Hampden Oxford  B01HJH7W0W    1.000000
# 477   NIKE Men's Air Max MVP Elite Mid Baseball Cleats  B00OBZVR66    0.619057
# 102  RIDGEMONT Monty Lo Women's Oiled Suede Walking...  B017UOZFH6    0.573017
# 491                  VANS Unisex Classic Slip-On Shoes  B00RQOMZOW    0.536507
# 479  adidas Performance Women's Matteo NUA Firm-Gro...  B00DQYP1EM    0.515588
# 323       Earth Origins London Women's Black 7 B(M) US  B005BB16BK    0.449446
# 134  Heart's Amanda-02 Women's Pointy Toe Chunky He...  B016VFGK56    0.408132
# 499          UGG Men's Classic Mini Bomber Winter Boot  B00RM65C7G    0.404158
# 425          Vans Atwood Unisex Kids' Low-Top Sneakers  B00HRGHTNG    0.392704
# 104                                B.O.C - Mens - Eric  B0093OM0R0    0.392704

# %%
content_recommender_cosine("content_recommender_cosine("Deer Stags Men's Hampden Oxford", products_df, 'maincat_Shoes')", products_df, 'maincat_Shoes')
# Out:
#                                           product_name        asin  similarity
# 500                    Deer Stags Men's Hampden Oxford  B01HJH7W0W    1.000000
# 477   NIKE Men's Air Max MVP Elite Mid Baseball Cleats  B00OBZVR66    0.619057
# 102  RIDGEMONT Monty Lo Women's Oiled Suede Walking...  B017UOZFH6    0.573017
# 491                  VANS Unisex Classic Slip-On Shoes  B00RQOMZOW    0.536507
# 479  adidas Performance Women's Matteo NUA Firm-Gro...  B00DQYP1EM    0.515588
# 323       Earth Origins London Women's Black 7 B(M) US  B005BB16BK    0.449446
# 134  Heart's Amanda-02 Women's Pointy Toe Chunky He...  B016VFGK56    0.408132
# 499          UGG Men's Classic Mini Bomber Winter Boot  B00RM65C7G    0.404158
# 425          Vans Atwood Unisex Kids' Low-Top Sneakers  B00HRGHTNG    0.392704
# 104                                B.O.C - Mens - Eric  B0093OM0R0    0.392704

# %% [markdown]
# ## Conclusion <a class="anchor" id="conc"></a>
#
# The content-based recommendation created finds similar products using cosine similarity on the product's TF-IDF matrix made from the description of the product. A general function that does this was created.
#
# *Next Notebook*: `colab_rec.ipynb`
